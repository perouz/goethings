# %%
import geothings as g
import draw as dr
from random import random
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
n = 10
points = [g.Point(random() * n, random() * n) for i in range(n)]

# %%
print points
# Out:
# [<geothings.Point object at 0x7fed207dced0>, <geothings.Point object at 0x7fed207dcdd0>, <geothings.Point object at 0x7fed207dc0d0>, <geothings.Point object at 0x7fed207dc090>, <geothings.Point object at 0x7fed207dc550>, <geothings.Point object at 0x7fed207dc9d0>, <geothings.Point object at 0x7fed207dcbd0>, <geothings.Point object at 0x7fed207dca90>, <geothings.Point object at 0x7fed207dcf90>, <geothings.Point object at 0x7fed207dcd90>]

# %%
dr.draw_points(points)

# %%
C = g.Chain(points)
C.vertices
# Out:
# [(2.440496166849667, 1.6584725938032119),
#  (3.5359287698116306, 2.7796208241666607),
#  (0.14908453813624822, 3.9538825481411024),
#  (8.666698844728128, 6.0516402911245235),
#  (5.197708039048332, 1.116128234561481),
#  (9.852949927451188, 8.989370917125406),
#  (0.004912822965517094, 4.57901342033839),
#  (5.332113623685624, 3.325829417054017),
#  (8.756223610184616, 0.18974162933035776),
#  (7.713229902498025, 2.679229360873079)]

# %%
dr.fancy_draw_chain(C)

# %%
v = C.points[2]
print v
# Out:
# (0.149084538136, 3.95388254814)

# %%
print C.pop(v)
# Out:
# (3.17214872825, -0.786507121853)

# %%
dr.fancy_draw_chain(C)

# %%
L1 = g.Line(2, 6, 25)
L2 = g.Line(-7, 2, 3)

# %%
L1.draw(-10, 10, 'g')
L2.draw(-10, 10, 'r')
p = L1.point_of_intersection(L2)
p.draw('b')
